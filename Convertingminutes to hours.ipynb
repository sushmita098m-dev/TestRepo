# %% [markdown]
# ### Converting minuts to hours

# %%
total_minutes= 150 
hours, remaining_minutes=divmod(total_minutes,60)
print(f"{total_minutes}minut is equal to {hours} hours and {remaining_minutes}minutes.")
# Out:
# 150minut is equal to 2 hours and 30minutes.

# %%
minutes=150
hours=minutes//60
print(hours)
# Out:
# 2

# %%
minutes=170
hours=minutes//60
remaining_minutes=minutes %60
print(f"{minutes} minutes is equlas to {hours} hours and {remaining_minutes} minutes.")
# Out:
# 170 minutes is equlas to 2 hours and 50 minutes.
